# %%
import os

os.environ.setdefault("KMP_DUPLICATE_LIB_OK", "TRUE")
# Conda env `tf`: faiss-cpu, sentence-transformers, torch, and torchvision are already installed.
pass

# %%
# import necessary libraries
import pandas as pd
pd.set_option('display.max_colwidth', 100)

# %%
df = pd.read_csv("sample_text.csv")
df.shape
# Out:
# (8, 2)

# %%
df
# Out:
#                                                                                   text  \
# 0                                        Meditation and yoga can improve mental health
# 1                     Fruits, whole grains and vegetables helps control blood pressure
# 2                                    These are the latest fashion trends for this week
# 3                                    Vibrant color jeans for male are becoming a trend
# 4                                                   The concert starts at 7 PM tonight
# 5                      Navaratri dandiya program at Expo center in Mumbai this october
# 6                                    Exciting vacation destinations for your next trip
# 7  Maldives and Srilanka are gaining popularity in terms of low budget vacation places
#
#   category
# 0   Health
# 1   Health
# 2  Fashion
# 3  Fashion
# 4    Event
# 5    Event
# 6   Travel
# 7   Travel

# %% [markdown]
# ### Step 1 : Create source embeddings for the text column

# %%
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer("all-mpnet-base-v2")
vectors = encoder.encode(df.text.tolist(), convert_to_numpy=True)
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
vectors.shape
# Out:
# (8, 768)

# %%
dim = vectors.shape[1]
dim
# Out:
# 768

# %% [markdown]
# ### Step 2 : Build a FAISS Index for vectors

# %%
import faiss

index = faiss.IndexFlatL2(dim)

# %% [markdown]
# ### Step 3 : Normalize the source vectors (as we are using L2 distance to measure similarity) and add to the index

# %%
index.add(vectors)

# %%
index
# Out:
# <faiss.swigfaiss.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x32b558ab0> >

# %% [markdown]
# ### Step 4 : Encode search text using same encorder and normalize the output vector

# %%
search_query = " eat a doctor a day keeps the apple away"
# search_query = "looking for places to visit during the holidays"
# search_query = "An apple a day keeps the doctor away"
vec = encoder.encode(search_query, convert_to_numpy=True)
vec.shape
# Out:
# (768,)

# %%
import numpy as np
svec = np.array(vec).reshape(1,-1)
svec.shape
# Out:
# (1, 768)

# %%
# faiss.normalize_L2(svec)

# %% [markdown]
# ### Step 5: Search for similar vector in the FAISS index created

# %%
distances, I = index.search(svec, k=2)
distances
# Out:
# array([[1.4270623, 1.7390413]], dtype=float32)

# %%
I
# Out:
# array([[1, 0]])

# %%
I.tolist()
# Out:
# [[1, 0]]

# %%
row_indices = I.tolist()[0]
row_indices
# Out:
# [1, 0]

# %%
df.loc[row_indices]
# Out:
#                                                                text category
# 1  Fruits, whole grains and vegetables helps control blood pressure   Health
# 0                     Meditation and yoga can improve mental health   Health

# %%
search_query
# Out:
# ' eat a doctor a day keeps the apple away'

# %% [markdown]
# You can see that the two results from the dataframe are similar to a search_query
